# %%
import regression as reg
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import networkx as nx

# %%
data = pd.read_csv('../Datasets/Updated_Team_Performance_With_Degree_Restricao.csv')
data.head()
# Out:
#              Owner                 Team League  \
# 0  Alan Smolinisky  LOS ANGELES DODGERS    MLB
# 1  Alan Smolinisky  LOS ANGELES DODGERS    MLB
# 2     Alex Meruelo      ARIZONA COYOTES    NHL
# 3     Alex Meruelo      ARIZONA COYOTES    NHL
# 4     Alex Meruelo      ARIZONA COYOTES    NHL
#
#                              Recipient    Amount  Election Year     Party  \
# 0      Americans for Tomorrow's Future  $10,000            2020       NaN
# 1                   Stand with Sanchez   $2,800            2020  Democrat
# 2  All For Our Country Leadership PAC    $5,000            2020  Democrat
# 3         Nevadans for Steven Horsford   $2,800            2020  Democrat
# 4         Esmeralda Soria for Congress     $500            2020  Democrat
#
#    Desempenho  Performance    Degree  Restricao
# 0       0.821        0.717  1.000000   0.652995
# 1       0.821        0.717  1.000000   0.652995
# 2       0.529        0.529  0.017699   0.529882
# ...

# %%
result = reg.logistic(data=data, formula='Performance ~ Degree')
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.686541
#          Iterations 4
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:            Performance   No. Observations:                 2432
# Model:                          Logit   Df Residuals:                     2430
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 May 2025   Pseudo R-squ.:                0.005326
# Time:                        14:22:09   Log-Likelihood:                -1669.7
# converged:                       True   LL-Null:                       -1678.6
# Covariance Type:            nonrobust   LLR p-value:                 2.351e-05
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
result = reg.logistic(data=data, formula='Performance ~ Restricao')
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.686995
#          Iterations 4
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:            Performance   No. Observations:                 2432
# Model:                          Logit   Df Residuals:                     2430
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 May 2025   Pseudo R-squ.:                0.004668
# Time:                        14:14:43   Log-Likelihood:                -1670.8
# converged:                       True   LL-Null:                       -1678.6
# Covariance Type:            nonrobust   LLR p-value:                 7.537e-05
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
result = reg.logistic(data=data, formula='Performance ~ Degree')
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.686541
#          Iterations 4
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:            Performance   No. Observations:                 2432
# Model:                          Logit   Df Residuals:                     2430
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 May 2025   Pseudo R-squ.:                0.005326
# Time:                        14:29:00   Log-Likelihood:                -1669.7
# converged:                       True   LL-Null:                       -1678.6
# Covariance Type:            nonrobust   LLR p-value:                 2.351e-05
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
result.plot_residuals()
# Out:
# 22.0% of average residuals inside

# %%
result.plot_residuals(data['Performance'])
# Out:
# 46.0% of average residuals inside

# %%
result.plot_residuals(data['Degree'])
# Out:
# 34.0% of average residuals inside

# %%
result.plot_residuals(data['Restricao'])
# Out:
# 34.0% of average residuals inside
